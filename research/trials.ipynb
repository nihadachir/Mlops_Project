# %% [markdown]
# ## Why we use ensure annotation and configbox

# %% [markdown]
# 1.ConfigBox

# %%
d={"key1": "value1", "key2": "value2"}
d["key1"]
# Out:
# 'value1'

# %%
d.key1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 d.key1
#
# AttributeError: 'dict' object has no attribute 'key1'

# %%
from box import ConfigBox
d1=ConfigBox({"key1": "value1", "key2": "value2"})

# %%
d1["key1"]
# Out:
# 'value1'

# %%
d1.key1
# Out:
# 'value1'

# %% [markdown]
# 2.Ensure Annotations

# %%
def multiply(a: int, b: int) -> int:
    return a * b

# %%
multiply(2, 3)
# Out:
# 6

# %%
multiply(3,'3')
# Out:
# '333'

# %%
from ensure import ensure_annotations
@ensure_annotations
def multiply(a: int, b: int) -> int:
    return a * b

# %%
multiply(2, 3)
# Out:
# 6

# %%
multiply(2, '2')
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 multiply(2, '2')
#
# File c:\Users\Lenovo\anaconda3\envs\mlproject\lib\site-packages\ensure\main.py:845, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     840     if not isinstance(value, templ):
#     841         msg = (
#     842             "Argument {arg} of type {valt} to {f} "
#     843             "does not match annotation type {t}"
#     844         )
# --> 845         raise EnsureError(msg.format(
#     846             arg=arg, f=self.f, t=templ, valt=type(value)
#     847         ))
#     849 return_val = self.f(*args, **kwargs)
#     850 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument b of type <class 'str'> to <function multiply at 0x000002B4D9FC27A0> does not match annotation type <class 'int'>
